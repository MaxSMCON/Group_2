# %% [markdown]
# ## Merge GDP and Food Prices File & Created a Revised Category Field
# This code has taken the Global Food Data Set and merged with GDP information
# Created a Revised Column for Generic Food Prices

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('global_food_prices.csv')
df.head(5)
# Out:
# C:\Users\rmudart\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
#
#           cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  \
# 0  Bread - Retail     0.0      AFN     15  Retail      5      KG         1
# 1  Bread - Retail     0.0      AFN     15  Retail      5      KG         2
# ...

# %%
#Create a New Column with Generic Categorization 
df['Category_Revised'] = df['cm_name'].str.split(' ').str[0]

# %%
#Display the Headers 
df.head(5)
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
#
#           cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  \
# 0  Bread - Retail     0.0      AFN     15  Retail      5      KG         1
# 1  Bread - Retail     0.0      AFN     15  Retail      5      KG         2
# 2  Bread - Retail     0.0      AFN     15  Retail      5      KG         3
# 3  Bread - Retail     0.0      AFN     15  Retail      5      KG         4
# 4  Bread - Retail     0.0      AFN     15  Retail      5      KG         5
#
#    mp_year  mp_price  mp_commoditysource Category_Revised
# ...

# %%
# NEED TO RENAME COLUMNS 
df=df.rename(columns={"adm0_name": "Country", "mp_year": "Year"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050638 entries, 0 to 2050637
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   adm0_id             float64
#  1   Country             object
#  2   adm1_id             int64
#  3   adm1_name           object
#  4   mkt_id              int64
#  5   mkt_name            object
#  6   cm_id               int64
#  7   cm_name             object
#  8   cur_id              float64
#  9   cur_name            object
#  10  pt_id               int64
#  11  pt_name             object
#  12  um_id               int64
#  13  um_name             object
#  14  mp_month            int64
#  15  Year                int64
#  16  mp_price            float64
#  17  mp_commoditysource  float64
#  18  Category_Revised    object
# dtypes: float64(4), int64(7), object(8)
# memory usage: 297.3+ MB

# %%
df2 = pd.read_csv('GDP.csv', encoding='latin-1')
# pd.read_csv('ml-100k/u.item', sep='|', names=m_cols , encoding='latin-1')
df2.head(5)
# Out:
#        Country                       Subject Descriptor              Units  \
# 0  Afghanistan  Gross domestic product, constant prices  National currency
# 1      Albania  Gross domestic product, constant prices  National currency
# 2      Algeria  Gross domestic product, constant prices  National currency
# 3      Andorra  Gross domestic product, constant prices  National currency
# 4       Angola  Gross domestic product, constant prices  National currency
#
#       Scale                      Country/Series-specific Notes      1991  \
# 0  Billions  Source: National Statistics Office Latest actu...       NaN
# 1  Billions  Source: IMF Staff Estimates. Official national...   252.921
# 2  Billions  Source: National Statistics Office Latest actu...  3,393.45
# 3  Billions  Source: National Statistics Office. Ministry o...       NaN
# 4  Billions  Source: National Statistics Office. Ministry o...   283.298
#
# ...

# %%
#Convert columns to Rows 
df2 = df2.melt(id_vars=["Country", "Subject Descriptor","Units","Scale","Country/Series-specific Notes"], 
        var_name="Year", 
        value_name="Value")

# %%
df2["Year"] = pd.to_numeric(df3["Year"],errors='coerce')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6336 entries, 0 to 6335
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        6304 non-null   object
#  1   Subject Descriptor             6272 non-null   object
#  2   Units                          6272 non-null   object
#  3   Scale                          6272 non-null   object
#  4   Country/Series-specific Notes  6272 non-null   object
#  5   Year                           6138 non-null   float64
#  6   Value                          6028 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 346.6+ KB

# %%
df2.head(5)
# Out:
#        Country                       Subject Descriptor              Units  \
# 0  Afghanistan  Gross domestic product, constant prices  National currency
# 1      Albania  Gross domestic product, constant prices  National currency
# 2      Algeria  Gross domestic product, constant prices  National currency
# 3      Andorra  Gross domestic product, constant prices  National currency
# 4       Angola  Gross domestic product, constant prices  National currency
#
#       Scale                      Country/Series-specific Notes    Year  \
# 0  Billions  Source: National Statistics Office Latest actu...  1991.0
# 1  Billions  Source: IMF Staff Estimates. Official national...  1991.0
# 2  Billions  Source: National Statistics Office Latest actu...  1991.0
# 3  Billions  Source: National Statistics Office. Ministry o...  1991.0
# 4  Billions  Source: National Statistics Office. Ministry o...  1991.0
#
#       Value
# 0       NaN
# 1   252.921
# 2  3,393.45
# 3       NaN
# 4   283.298

# %%
#Merged Data Set with Global Food Prices and GDP Information 

df5 = pd.merge(
    left=df,
    right=df2,
    left_on=('Country', 'Year'),
    right_on=('Country','Year'),
    how='left'
)

# %%
df5.head(5)
# Out:
#    adm0_id      Country  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
#
#           cm_name  cur_id cur_name  ...  mp_month  Year  mp_price  \
# 0  Bread - Retail     0.0      AFN  ...         1  2014      50.0
# 1  Bread - Retail     0.0      AFN  ...         2  2014      50.0
# 2  Bread - Retail     0.0      AFN  ...         3  2014      50.0
# 3  Bread - Retail     0.0      AFN  ...         4  2014      50.0
# 4  Bread - Retail     0.0      AFN  ...         5  2014      50.0
#
#   mp_commoditysource  Category_Revised  \
# 0                NaN             Bread
# 1                NaN             Bread
# ...

# %%
df5.to_csv('GDP_FOODPRICE.csv')
